# %%
from astropy.io import fits

file = "/Users/gustavo/Downloads/j02-FRIN-b20201225e0125-Z-00-MainSurvey.fits"

# %% [markdown]
# #### Lendo header original

# %%
fits.open(file)[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 9216 / Axis length
# NAXIS2  =                 9232 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '2021-02-03T02:42:35' / Time of last modification
# OBJECT  = 'SPLUS-s38s28'       / Name of the object observed
# DATE    = '2021-02-03T03:31:27' / date of file creation
# TIME    = '23:28:33.595 to 23:29:29.608' / ~ Start & Stop of Exposure
# N_PRM0  =                   74 / Status
# PG0_0   =                57376 / Camera Flags,
# PG0_2   =                    0 / Continuous Clear Mode,
# PG0_3   =               16.227 / Frame Clear Time, HH:MM:SS.sss
# PG0_4   =               16.227 / CCD Read Time, HH:MM:SS.sss
# PG0_5   =               10.169 / Cryo Current, Amps
# ...

# %% [markdown]
# ### Lendo o nosso próprio header com astropy

# %%
fits.getheader("../output.fits")
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 9216 / Axis length
# NAXIS2  =                 9232 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '2021-02-03T02:42:35' / Time of last modification
# OBJECT  = 'SPLUS-s38s28' / Name of the object observed
# DATE    = '2021-02-03T03:31:27' / date of file creation
# TIME    = '23:28:33.595 to 23:29:29.608' / ~ Start & Stop of Exposure
# N_PRM0  =                   74 / Status
# PG0_0   =                57376 / Camera Flags,
# PG0_2   =                    0 / Continuous Clear Mode,
# PG0_3   =               16.227 / Frame Clear Time, HH:MM:SS.sss
# PG0_4   =               16.227 / CCD Read Time, HH:MM:SS.sss
# PG0_5   =               10.169 / Cryo Current, Amps
# ...
